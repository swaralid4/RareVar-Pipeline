# %%
import pandas as pd
import os

# Fix working directory to project root
os.chdir(os.path.expanduser("~/RareVar-Pipeline"))

df = pd.read_csv("data/processed/variants_raw.csv")
print("Shape:", df.shape)
print("\nMissing values:\n", df.isnull().sum())
print("\nQUAL stats:\n", df["QUAL"].describe())
print("\nAF stats:\n", df["AF"].describe())
print("\nCLNSIG distribution:\n", df["CLNSIG"].value_counts())
# Out:
# Shape: (2329288, 10)
#
# Missing values:
#  CHROM     0
# POS       0
# ID        0
# REF       0
# ALT       0
# QUAL      0
# FILTER    0
# AF        0
# GENE      0
# CLNSIG    0
# dtype: int64
#
# QUAL stats:
#  count    2329288.0
# mean         100.0
# std            0.0
# min          100.0
# 25%          100.0
# 50%          100.0
# 75%          100.0
# max          100.0
# Name: QUAL, dtype: float64
#
# AF stats:
#  count    2.329288e+06
# mean     3.496357e-02
# std      1.284150e-01
# min      0.000000e+00
# 25%      1.996810e-04
# 50%      3.993610e-04
# 75%      2.795530e-03
# max      1.000000e+00
# Name: AF, dtype: float64
#
# CLNSIG distribution:
#  CLNSIG
# .    2329288
# Name: count, dtype: int64
